# %%
# %matplotlib inline
import numpy as np
import scipy.stats as st
#import statsmodels.api as sm
import pandas as pd
import math
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Datasets/health_ita.csv", sep=",",decimal=".")
#print(data["Indicator Name"].unique())
data[data["Indicator Name"] == "Hospital beds (per 1,000 people)"].head()
# Out:
#      Country Name Country ISO3  Year                    Indicator Name  \
# 1065        Italy          ITA  2018  Hospital beds (per 1,000 people)
# 1066        Italy          ITA  2017  Hospital beds (per 1,000 people)
# 1067        Italy          ITA  2016  Hospital beds (per 1,000 people)
# 1068        Italy          ITA  2015  Hospital beds (per 1,000 people)
# 1069        Italy          ITA  2014  Hospital beds (per 1,000 people)
#
#       Indicator Code  Value
# 1065  SH.MED.BEDS.ZS   3.14
# 1066  SH.MED.BEDS.ZS   3.18
# 1067  SH.MED.BEDS.ZS   3.17
# 1068  SH.MED.BEDS.ZS   3.20
# 1069  SH.MED.BEDS.ZS   3.21

# %%
data = pd.read_csv("Datasets/health_ita.csv", sep=",",decimal=".")
data = data.drop(columns=['Country Name','Country ISO3'])
data.head()
# Out:
#    Year                                     Indicator Name     Indicator Code  \
# 0  2012  Proportion of women subjected to physical and/...     SG.VAW.1549.ZS
# 1  2019  Total alcohol consumption per capita, female (...  SH.ALC.PCAP.FE.LI
# 2  2015  Total alcohol consumption per capita, female (...  SH.ALC.PCAP.FE.LI
# 3  2010  Total alcohol consumption per capita, female (...  SH.ALC.PCAP.FE.LI
# 4  2005  Total alcohol consumption per capita, female (...  SH.ALC.PCAP.FE.LI
#
#      Value
# 0  7.00000
# 1  3.53716
# 2  3.40767
# 3  3.21568
# 4  3.72126

# %%
beds = data[data["Indicator Name"] == "Hospital beds (per 1,000 people)"]
beds=beds.drop('Indicator Code',axis=1)
beds.head()
# Out:
#       Year                    Indicator Name  Value
# 1065  2018  Hospital beds (per 1,000 people)   3.14
# 1066  2017  Hospital beds (per 1,000 people)   3.18
# 1067  2016  Hospital beds (per 1,000 people)   3.17
# 1068  2015  Hospital beds (per 1,000 people)   3.20
# 1069  2014  Hospital beds (per 1,000 people)   3.21

# %%
plt.bar(beds['Year'], beds['Value'], width=1) 
plt.title("Hospital beds (per 1,000 people)")
plt.show()

# %%
#VARIANTE!!!!!!!!!!!!!!!!!!!!!!!!!
plt.vlines(beds['Year'], 0, beds['Value'], alpha=0.5) 
plt.plot(beds['Year'], beds['Value'],'.') 
plt.title("Hospital beds (per 1,000 people)")
plt.show()

# %%
#VARIANTE!!!!!!!!!!!!!!!!!!!!!!!!!
plt.plot(beds['Year'], beds['Value'], alpha=0.7)
plt.fill_between(beds['Year'],beds['Value'],alpha=0.5, color='#BFE7F1')
#plt.plot(beds['Year'], beds['Value'],".", color="blue") 
plt.title("Letti di ospedale (per 1,000 persone)")
plt.xlabel("Anno")
plt.ylim(0)
plt.show()

# %%
data1 = pd.read_csv("Datasets/Posti_letto_per_struttura_ospedaliera_2020.csv", sep=";",encoding='cp1252')
data1.head()
# Out:
#    Anno  Codice Regione Descrizione Regione  Codice Azienda  Tipo Azienda  \
# 0  2020              10            PIEMONTE             203             1
# 1  2020              10            PIEMONTE             203             1
# 2  2020              10            PIEMONTE             203             1
# 3  2020              10            PIEMONTE             203             1
# 4  2020              10            PIEMONTE             203             1
#
#    Codice struttura                   Denominazione struttura  \
# 0             10030  OSPEDALI RIUNITI PINEROLO
# 1             10030  OSPEDALI RIUNITI PINEROLO
# 2             10030  OSPEDALI RIUNITI PINEROLO
# 3             10079                   OSPEDALI RIUNITI RIVOLI
# 4             10079                   OSPEDALI RIUNITI RIVOLI
#
#                                   Indirizzo  Codice Comune  \
# 0  VIA BRIGATA CAGLIARI 39                            1191
# 1  VIA BRIGATA CAGLIARI 39                            1191
# ...

# %%
postiLetto2020=data1["Totale posti letto"].sum()
#abbiamo diviso per la dimensione della popolazione italiana nel 2020 e moltiplicato per 1000
#così abbiamo ottenuto il numero di posti letto per 1000 persone in Italia
postiLetto2020/60244639*1000
# Out:
# 3.4263463675166186

# %%
postiLetto2020Regioni=data1[["Descrizione Regione","Totale posti letto"]]
postiLetto2020Regioni=postiLetto2020Regioni.groupby(['Descrizione Regione']).sum()
postiLetto2020Regioni.sort_index(inplace=True)

postiLetto2020Regioni.head()
# Out:
#                      Totale posti letto
# Descrizione Regione
# ABRUZZO                            4323
# BASILICATA                         1804
# CALABRIA                           5721
# CAMPANIA                          17184
# EMILIA ROMAGNA                    15869

# %%
popolazioneRegioni2020=pd.read_csv("Datasets/Popolazione_Regioni_2020.csv", sep=",")
popolazioneRegioni2020.head()
popolazioneRegioni2020 = popolazioneRegioni2020.groupby(['Territorio']).sum()
popolazioneRegioni2020 = popolazioneRegioni2020[["Value"]]
popolazioneRegioni2020= popolazioneRegioni2020.rename(columns={'Value':'Totale abitanti'})
popolazioneRegioni2020=popolazioneRegioni2020.drop("Trentino Alto Adige / Südtirol")
popolazioneRegioni2020.sort_index(inplace=True)
popolazioneRegioni2020 =popolazioneRegioni2020.set_index(postiLetto2020Regioni.index)

popolazioneRegioni2020.head()
# Out:
#                      Totale abitanti
# Descrizione Regione
# ABRUZZO                      5175764
# BASILICATA                   2213016
# CALABRIA                     7576440
# CAMPANIA                    22848572
# EMILIA ROMAGNA              17856476

# %%
postiLetto2020norm = [x[1]["Totale posti letto"] / popolazioneRegioni2020.loc[x[0]].values[0] *1000 for x in postiLetto2020Regioni.iterrows()]

# %%
cause_morte = pd.read_csv("./Datasets_non_utilizzati/cause_morte.csv", sep=";", decimal=".", thousands=',')
cause_morte = cause_morte.set_index("Cause di morte")
cause_morte.head()
# Out:
#                                                       2003    2004    2005  \
# Cause di morte
# Alcune malattie infettive e parassitarie              7373    6579    7025
# Tumori                                              167144  166439  166546
# Malattie del sangue e degli organi ematopoietic...    2376    2386    2558
# Malattie endocrine, nutrizionali e metaboliche       24027   21774   23534
# Disturbi psichici e comportamentali                   9302    7851    8798
#
#                                                       2006    2007    2008  \
# Cause di morte
# Alcune malattie infettive e parassitarie              7361    7936    8393
# Tumori                                              168664  171625  172783
# Malattie del sangue e degli organi ematopoietic...    2564    2726    2607
# Malattie endocrine, nutrizionali e metaboliche       23556   24484   24999
# Disturbi psichici e comportamentali                   8880    9300   13915
#
# ...

# %%
cause_morte_years = cause_morte.T
cause_morte_years.index.names = ["Year"]
cause_morte_years["Totale"].head()
# Out:
# Year
# 2003    588897
# 2004    545051
# 2005    568328
# 2006    558614
# 2007    572881
# Name: Totale, dtype: int64

# %%
(cause_morte_years["Totale"]/100000).plot.line()
plt.title("Numero di morti annuali in Italia (per 100000)")
plt.xlabel("Anno")
plt.show()

# %%
cause_morte_years_no_covid = cause_morte_years["Totale"]-cause_morte_years["Covid-19"]
cause_morte_years_no_covid.plot.line()
plt.ylim(0)
plt.show()

# %%
popolazione_year = pd.read_csv("Datasets/popolazione_03_21.csv", sep=";", index_col=0)

morti_per_year = cause_morte_years["Totale"]
morti_per_year_norm = {}
for year in range(2003, 2022):
    morti_per_year_norm[str(year)] = morti_per_year.loc[str(year)]/popolazione_year.loc[year][0]


#morti_per_year_norm = pd.DataFrame.from_dict(morti_per_year_norm, orient='index',columns=['Rapporto morti/popolazione'])
morti_per_year_norm= pd.Series(morti_per_year_norm)
morti_per_year_norm.head()
# Out:
# C:\Users\Utente\AppData\Local\Temp\ipykernel_13392\959873803.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   morti_per_year_norm[str(year)] = morti_per_year.loc[str(year)]/popolazione_year.loc[year][0]
# 2003    0.010298
# 2004    0.009461
# 2005    0.009791
# 2006    0.009584
# 2007    0.009791
# dtype: float64

# %%
morti_per_year_norm.plot.line(legend=False)
plt.ylim(0)
plt.show()

# %%
plt.subplot(1, 2, 1)
cause_morte_years["Totale"].plot.line()
plt.ylim(0)
#plt.yticks([400000, 500000, 600000, 700000])

plt.subplot(1, 2, 2)
morti_per_year_norm.plot.line(legend=False)
plt.ylim(0)
plt.tight_layout()

plt.show()

# %%
cause_morte = pd.read_csv("./Datasets_non_utilizzati/cause_morte.csv", sep=";", decimal=".", thousands=',')
cause_morte = cause_morte.set_index("Cause di morte")
cause_morte_years = cause_morte.T
cause_morte_years.index.names = ["Year"]
cause_morte_years_no_totale=cause_morte_years.drop(columns=["Totale"])
cause_morte_years_no_totale.plot.line()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
cause_morte_years_più_morti=cause_morte_years[["Tumori","Malattie del sistema circolatorio"]]
cause_morte_years_più_morti.plot.line()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim(0)
plt.show()

# %%
cause_morte_years_medie=cause_morte_years.drop(columns=["Totale","Tumori","Malattie del sistema circolatorio","Covid-19","Complicazioni della gravidanza, del parto e del puerperio","Malformazioni congenite ed anomalie cromosomiche","Alcune condizioni morbose che hanno origine nel periodo perinatale","Malattie del sangue e degli organi ematopoietici ed alcuni disturbi del sistema immunitario","Malattie della cute e del tessuto sottocutaneo ","Malattie del sistema osteomuscolare e del tessuto connettivo"])
#cause_morte_years.head()
cause_morte_years_medie.plot.line()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5)).astype({'col1': 'int32'})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 4
#       2 #cause_morte_years.head()
#       3 cause_morte_years_medie.plot.line()
# ----> 4 plt.legend(loc='center left', bbox_to_anchor=(1, 0.5)).astype({'col1': 'int32'})
#       5 plt.show()
#
# AttributeError: 'Legend' object has no attribute 'astype'

# %%
cause_morte_years_meno_morti=cause_morte_years[["Complicazioni della gravidanza, del parto e del puerperio","Malformazioni congenite ed anomalie cromosomiche","Alcune condizioni morbose che hanno origine nel periodo perinatale","Malattie del sangue e degli organi ematopoietici ed alcuni disturbi del sistema immunitario","Malattie della cute e del tessuto sottocutaneo ","Malattie del sistema osteomuscolare e del tessuto connettivo"]]
cause_morte_years_meno_morti.plot.line()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
statoSaluteRegioniAllYears=pd.read_csv("Datasets_non_utilizzati/Stato di salute-regioni.csv", sep=";",decimal=",",thousands=".")
statoSaluteRegioniAllYears.head()
# Out:
#    Tempo            Territorio  buona salute  almeno una malattia cronica  \
# 0   2009              Piemonte        2996.0                       1718.0
# 1   2009         Valle d'Aosta          88.0                         48.0
# 2   2009               Liguria        1088.0                        681.0
# 3   2009             Lombardia        6748.0                       3757.0
# 4   2009  Trentino-Alto Adige          804.0                        340.0
#
#    almeno due malattie croniche
# 0                         875.0
# 1                          22.0
# 2                         378.0
# 3                        1856.0
# 4                         142.0

# %%
statoSaluteAllYears = statoSaluteRegioniAllYears.drop(columns="Territorio")
statoSaluteAllYears=statoSaluteAllYears.groupby(["Tempo"]).sum()
statoSaluteAllYears.head()
# Out:
#        buona salute  almeno una malattia cronica  almeno due malattie croniche
# Tempo
# 2009        41338.0                      23140.0                       12125.0
# 2010        42347.0                      23106.0                       12053.0
# 2011        42328.0                      22996.0                       12008.0
# 2012        42528.0                      23154.0                       12299.0
# 2013        42354.0                      22887.0                       12074.0

# %%
statoSaluteAllYears.plot.line()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
personaleMedicoTotaleAllYears=pd.read_csv("Datasets_non_utilizzati/Personale sanitario totale_2013_2022.csv", sep=";",decimal=",",thousands=".")
personaleMedicoTotaleAllYears=personaleMedicoTotaleAllYears.set_index("Profilo professionale").T
personaleMedicoTotaleAllYears.head()
# Out:
# Profilo professionale  Totale medici (generici e specialisti)
# 2013                                                    38.95
# 2014                                                    39.11
# 2015                                                    38.70
# 2016                                                    39.86
# 2017                                                    40.25

# %%
#NON TENGO CONTO DI INFERMIERI, FARMACISTI, ETC. IN QUESTO GRAFICO
personaleMedicoTotaleAllYears.plot.line(legend=False)
plt.title("Numero di medici (generici e specialisti) per 10'000 persone")
plt.ylim(0,50)
plt.show()

# %%
personaleMedicoAllYears=pd.read_csv("Datasets_non_utilizzati/Personale sanitario_categorie.csv", sep=";",decimal=",",thousands=".")
personaleMedicoAllYears=personaleMedicoAllYears.set_index("Profilo professionale").T
personaleMedicoAllYears["Totale"]= personaleMedicoAllYears.sum(axis=1)
personaleMedicoAllYears
personaleMedicoAllYears.head()
# Out:
# Profilo professionale  Medici specialisti  Medici generici  Odontoiatri  \
# 2013                                29.95             9.00         7.80
# 2014                                30.24             8.86         7.89
# 2015                                29.80             8.90         7.90
# 2016                                30.87             8.99         8.08
# 2017                                31.18             9.07         8.26
#
# Profilo professionale  Ostetriche  Professioni sanitarie infermieristiche  \
# 2013                         2.49                                   50.74
# 2014                         2.59                                   53.17
# 2015                         2.59                                   54.89
# 2016                         2.75                                   56.14
# 2017                         2.78                                   58.50
#
# Profilo professionale  Farmacisti  Totale
# 2013                        11.35  111.33
# ...

# %%
#TENGO CONTO DI INFERMIERI, FARMACISTI, ETC. IN QUESTO GRAFICO
personaleMedicoAllYears.Totale.plot.line()
plt.title("Numero di personale sanitario per 10'000 persone")
plt.ylim(0,140)
plt.show()

# %%
#CONFRONTO TUTTE LE PROFESSIONI SANITARIE
personaleMedicoAllYears.plot.line()
handles, labels = plt.gca().get_legend_handles_labels()
order=[4,0,5,1,2,3]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order],loc='center left', bbox_to_anchor=(1, 0.5)) 
plt.title("Numero di professionisti sanitari per 10'000 persone")
plt.show()

# %%
mediciSpecialistiAllYears=pd.read_csv("Datasets_non_utilizzati/Personale sanitario_medici specialisti.csv", sep=";",decimal=",",thousands=".")
mediciSpecialistiAllYears=mediciSpecialistiAllYears.set_index("Profilo professionale").T
mediciSpecialistiAllYears= mediciSpecialistiAllYears.drop(columns=["Altri medici specialisti"])
mediciSpecialistiAllYears.head()
# Out:
# Profilo professionale  Anestesisti  Cardiologi  Chirurghi  Gastroenterologi  \
# 2013                          2.01        2.14       1.49              0.57
# 2014                          2.06        2.18       1.40              0.58
# 2015                          1.96        2.11       1.42              0.55
# 2016                          2.09        2.18       1.46              0.56
# 2017                          2.15        2.20       1.49              0.57
#
# Profilo professionale  Geriatri  Neurologi  Oncologi  Ortopedici  \
# 2013                       0.71       1.12      0.73        1.53
# 2014                       0.73       1.10      0.74        1.57
# 2015                       0.66       1.03      0.72        1.51
# 2016                       0.69       1.08      0.74        1.56
# 2017                       0.71       1.10      0.76        1.52
#
# Profilo professionale  Otorinolaringoiatri  Urologi  Pediatri
# ...

# %%
mediciSpecialistiAllYears.plot.line()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
laureatiMedicina=pd.read_csv("Datasets/Laureati_medicina_2010_2021.csv", sep=";",decimal=",",thousands=".")
laureatiMedicina=laureatiMedicina.set_index("Anno").T
laureatiMedicina.head()
# Out:
# Anno  Laureati
# 2011     10961
# 2012     11717
# 2013     12255
# 2014     12393
# 2015     13515

# %%
laureatiMedicina.plot.line(legend=False)
plt.title("Numero di laureati annuali in Italia")
plt.ylim(0,18000)
plt.xlabel("Anno")
plt.show()

# %%
medici_esteri_per_paese = pd.read_csv("Datasets/medici_esteri_2021.csv",sep=",")
medici_esteri_per_paese= medici_esteri_per_paese.drop(columns=["COU","CO2","YEA","VAR","Variable","Flag Codes","Flags"])
medici_italiani_per_paese=medici_esteri_per_paese[medici_esteri_per_paese["Country of origin"]=="Italy"]
medici_italiani_per_paese_2022 = medici_italiani_per_paese[medici_italiani_per_paese["Year"]==2021]
medici_italiani_per_paese_2022.head()
# Out:
#        Country Country of origin  Year  Value
# 11788  Austria             Italy  2021     59
# 11811  Belgium             Italy  2021   1124
# 11834   Canada             Italy  2021    120
# 11845  Czechia             Italy  2021      4
# 11868  Finland             Italy  2021     69

# %%
medici_italiani_per_paese_2022.set_index("Country").drop(columns="Year").sort_values(by='Value',ascending=False).plot.bar(legend=False)
plt.title("Numero di medici italiani all'estero per paese nel 2022")
plt.xlabel("Paese")
plt.show()

# %%
medici_esteri_per_paese_inflow = pd.read_csv("Datasets/medici_esteri_annui.csv",sep=",")
medici_esteri_per_paese_inflow = medici_esteri_per_paese_inflow.drop(columns=["COU","CO2","YEA","VAR","Variable","Flag Codes","Flags"])
medici_italiani_per_paese_inflow= medici_esteri_per_paese_inflow[medici_esteri_per_paese_inflow["Country of origin"]=="Italy"]
#print(medici_italiani_per_paese_inflow[medici_italiani_per_paese_inflow["Year"]==2014])
#print(medici_italiani_per_paese_inflow[medici_italiani_per_paese_inflow["Year"]==2015])
medici_italiani_totale_inflow= medici_italiani_per_paese_inflow.groupby(["Year"]).sum()
medici_italiani_totale_inflow=medici_italiani_totale_inflow.loc[2011:2021]
medici_italiani_totale_inflow.head()
# Out:
#                                                 Country  \
# Year
# 2011  AustriaBelgiumCanadaDenmarkFinlandFranceGerman...
# 2012  AustriaBelgiumCanadaDenmarkFinlandFranceGerman...
# 2013  AustriaBelgiumCanadaDenmarkFinlandFranceGerman...
# 2014  AustriaBelgiumCanadaDenmarkFinlandFranceGerman...
# 2015  AustriaBelgiumCanadaDenmarkFinlandFranceGerman...
#
#                                       Country of origin  Value
# Year
# 2011  ItalyItalyItalyItalyItalyItalyItalyItalyItalyI...   1030
# 2012  ItalyItalyItalyItalyItalyItalyItalyItalyItalyI...   1086
# 2013  ItalyItalyItalyItalyItalyItalyItalyItalyItalyI...   1306
# 2014  ItalyItalyItalyItalyItalyItalyItalyItalyItalyI...   1616
# 2015  ItalyItalyItalyItalyItalyItalyItalyItalyItalyI...   1112

# %%
medici_italiani_totale_inflow.plot.line()
#plt.ylim(0)
plt.show()

# %%
medici_italiani_totale_inflow.plot.line()
plt.xticks(np.arange(2000, 2023,2))
plt.xlim(2011)
medici_italiani_per_paese.groupby("Year").sum().plot.bar()
plt.show()

# %%
physicians_countries_2018_2022=pd.read_csv("Datasets/Active_physicians_per_country_2018_2022.csv",sep=",")
physicians_countries_2018_2022= physicians_countries_2018_2022[["Country", "OBS_VALUE", "TIME_PERIOD"]]
physicians_countries_2018_2022.head()
# Out:
#     Country  OBS_VALUE  TIME_PERIOD
# 0  Bulgaria       4.22         2018
# 1  Bulgaria       4.24         2019
# 2  Bulgaria       4.28         2020
# 3  Bulgaria       4.30         2021
# 4     Chile       1.91         2018

# %% [markdown]
# # physicians_countries_2020 = physicians_countries_2018_2022[physicians_countries_2018_2022["TIME_PERIOD"]==2020]
# physicians_countries_2020 = physicians_countries_2020.set_index("Country").drop("Greece").drop(columns=["TIME_PERIOD"]).sort_values(by='OBS_VALUE',ascending=False)
# physicians_countries_2020.plot.bar(legend=False)
# plt.title("Numero totale di medici per paese per 1000 abitanti nel 2020")
# plt.show()

# %%
physicians_countries_2018 = physicians_countries_2018_2022[physicians_countries_2018_2022["TIME_PERIOD"]==2018]
physicians_countries_2018 = physicians_countries_2018.set_index("Country").drop("Greece").drop(columns=["TIME_PERIOD"]).sort_values(by='OBS_VALUE',ascending=False)
physicians_countries_2018.plot.bar(legend=False)
plt.title("Numero totale di medici per paese per 1000 abitanti nel 2018 ")
plt.show()

# %%
posti_letto_2022=pd.read_csv("Datasets/Posti_letto_2022.csv",sep=";",decimal=",",thousands=".", index_col=0)
posti_letto_2022=posti_letto_2022.drop("Totale posti letto")
myexplode=[0.1,0]
_,_,labels=plt.pie(posti_letto_2022.Totale,explode=myexplode,autopct='%1.1f%%',labels=["Pubblici","Accreditati"],colors=["cornflowerblue","coral"])
plt.title("Posti letto nel 2022")
plt.setp(labels,color='white',fontweight='bold')
plt.show()

# %%
strutture_sanitarie_2022=pd.read_csv("Datasets/Strutture_sanitarie_2022.csv",sep=";",decimal=",",thousands=".", index_col=0)
myexplode=[0.1,0]
_,_,labels=plt.pie(strutture_sanitarie_2022["Ambulatori e Laboratori"],explode=myexplode,autopct='%1.1f%%',labels=["Pubblici","Accreditati"],colors=["cornflowerblue","coral"])
plt.title("Ambulatori e Laboratori nel 2022")
plt.setp(labels,color='white',fontweight='bold')
plt.show()

# %%
private_pubbliche_anni=pd.read_csv("Datasets/Strutture_private_pubbliche.csv",sep=";",decimal=",",thousands=".", index_col=0)
private_pubbliche_anni.T.plot.bar()
plt.title("Strutture private e pubbliche negli anni")
plt.xlabel("Anno")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
medici_anni = pd.read_csv("Datasets/Età_medici_2022.csv",sep=";",decimal=",",thousands=".",index_col=0)
medici_anni.head()
#tot=41707/59641488*10000
# Out:
#       Da 0 a 6 anni  Da 6 a 13 anni  Da 13 a 20 anni  Da 20 a 27 anni  \
# Anno
# 2009            109             827             6811            16040
# 2010            124             733             5738            14410
# 2011             98             703             5035            13260
# 2012             69             554             4231            12120
# 2013             72             581             3724            11540
#
#       Oltre 27 anni  Totale
# Anno
# 2009          22422   46209
# 2010          24873   45878
# 2011          26965   46061
# 2012          28463   45437
# 2013          29286   45203

# %%
medici_anni["Totale"].plot.bar()
plt.ylim(0)
plt.title("Totale medici di medicina generale")
plt.show()

# %%
medici_anni.drop(columns=["Totale"]).plot.line()
plt.title("Anzianità di laurea dei medici di medicina generale negli anni")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
istituti_riabilitazione_2022 = pd.read_csv("Datasets/Istituti_riabilitazione_2022.csv",sep=";",decimal=",",thousands=".",index_col=0)
istituti_riabilitazione_2022
# Out:
#                      Quantità
# Tipo
# Pubblici                  253
# Privati accreditati       927
# Totale                   1180

# %%
myexplode=[0.1,0]
_,_,labels=plt.pie(istituti_riabilitazione_2022["Quantità"].drop("Totale"),explode=myexplode,autopct='%1.1f%%',labels=["Pubblici","Accreditati"],colors=["cornflowerblue","coral"])
plt.title("Numero di istituti o centri di riabilitazione nel 2022")
plt.setp(labels,color='white',fontweight='bold')
plt.show()

# %%
spesa_farmaceutica_2022 = pd.read_csv("Datasets_non_utilizzati/spesa_farmaceutica_nazionale_2022.csv",sep=";",decimal=",",thousands=".",index_col=0)
spesa_farmaceutica_2022=spesa_farmaceutica_2022.drop(columns=["Descrizione Aggregazione","Data Aggiornamento"])
spesa_farmaceutica_2022.head()
# Out:
#                      Importo Totale
# Anno di Riferimento
# 2008                     6200137000
# 2009                     6853186000
# 2010                     7431905000
# 2011                     7784957000
# 2012                     7856752000

# %%
#POTREBBERO ESSERE AUMENTATI PERCHé è AUMENTATO IL COSTO DEI SINGOLI FARMACI
(spesa_farmaceutica_2022/1000000).plot.bar(legend=False, color="cornflowerblue")
plt.title("Spesa farmaceutica nazionale")
plt.ylabel("Milioni")
plt.show()

# %%
conto_economico_2022 = pd.read_csv("Datasets_non_utilizzati/conto_economico_2022.csv",sep=";",decimal=".")
conto_economico_2022=conto_economico_2022.set_index("Codice Voce Contabile")

# %%
risultato_di_esercizio_2008_2022=pd.read_csv("Datasets_non_utilizzati/risultato_di_esercizio_2008_2022.csv",sep=";",decimal=".",index_col=0)
risultato_di_esercizio_2008_2022.head()
# Out:
#                      Importo Totale
# Anno di Riferimento
# 2008                  -4.135147e+09
# 2009                  -4.073434e+09
# 2010                  -3.224921e+09
# 2011                  -1.835158e+09
# 2012                   8.931550e+06

# %%
#NEL 2010 CON IL GOVERNO MONTI C'è STATA REVISIONE SPESA PUBBLICA:
#NON SI è PIù IN NEGATIVO PERCHè SI INVESTE DI MENO NELLA SANITà
(risultato_di_esercizio_2008_2022["Importo Totale"]/1000000).plot.bar(legend=False)
plt.title("Risultato di esercizio del SSN in Italia")
plt.xlabel("Anno")
plt.ylabel("Milioni")
plt.show()

# %%
rendiconto_2022=pd.read_csv("Datasets_non_utilizzati/rendiconto_2022.csv",sep=";",decimal=".",encoding='latin-1')
rendiconto_2022.head()
# Out:
#    Esercizio Finanziario  Stato di Previsione Descrizione Amministrazione  \
# 0  Esercizio Finanziario                   15      MINISTERO DELLA SALUTE
# 1  Esercizio Finanziario                   15      MINISTERO DELLA SALUTE
# 2  Esercizio Finanziario                   15      MINISTERO DELLA SALUTE
# 3  Esercizio Finanziario                   15      MINISTERO DELLA SALUTE
# 4  Esercizio Finanziario                   15      MINISTERO DELLA SALUTE
#
#                         Descr. Centro Responsabilità  Codice Azione  \
# 0  GABINETTO ED UFFICI DI DIRETTA COLLABORAZIONE ...              1
# 1  GABINETTO ED UFFICI DI DIRETTA COLLABORAZIONE ...              1
# 2  GABINETTO ED UFFICI DI DIRETTA COLLABORAZIONE ...              1
# 3  GABINETTO ED UFFICI DI DIRETTA COLLABORAZIONE ...              2
# 4  GABINETTO ED UFFICI DI DIRETTA COLLABORAZIONE ...              2
#
#                    Descrizione Azione  Numero Capitolo  \
# ...
